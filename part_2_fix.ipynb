# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%time
df = pd.read_pickle("data/pickle.pkl.xz")
# Out:
# Wall time: 1.54 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2997979 entries, 0 to 2997978
# Data columns (total 7 columns):
# x           uint16
# y           uint16
# obj         uint16
# size        uint32
# seq         uint16
# filename    category
# time        datetime64[ns]
# dtypes: category(1), datetime64[ns](1), uint16(4), uint32(1)
# memory usage: 62.9 MB

# %%
df.tail(20)
# Out:
#            x    y  obj      size  seq                           filename  \
# 2997959  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997960  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997961  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997962  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997963  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997964  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997965  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997966  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997967  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997968  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997969  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997970  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997971  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997972  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997973  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997974  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997975  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997976  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997977  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
# 2997978  133  254   32  43088232   58  14-16\20170824152302_100.h264.txt
#
#                        time
# 2997959 2017-08-24 15:32:21
# 2997960 2017-08-24 15:32:21
# 2997961 2017-08-24 15:32:21
# 2997962 2017-08-24 15:32:21
# 2997963 2017-08-24 15:32:21
# 2997964 2017-08-24 15:32:21
# 2997965 2017-08-24 15:32:21
# 2997966 2017-08-24 15:32:21
# 2997967 2017-08-24 15:32:21
# 2997968 2017-08-24 15:32:21
# 2997969 2017-08-24 15:32:21
# 2997970 2017-08-24 15:32:21
# 2997971 2017-08-24 15:32:21
# 2997972 2017-08-24 15:32:21
# 2997973 2017-08-24 15:32:21
# 2997974 2017-08-24 15:32:21
# 2997975 2017-08-24 15:32:21
# 2997976 2017-08-24 15:32:21
# 2997977 2017-08-24 15:32:21
# 2997978 2017-08-24 15:32:21

# %%
im = imread('data/paths0.png')

# %%
time_df = df.groupby(['obj', 'filename']).agg({'time':['min', 'max']})

# %%
time_df.head()
# Out:
#                                                      time
#                                                       min                 max
# obj filename
# 0   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09
#     14-16\20170817014225_100.h264.txt 2017-08-17 01:42:25 2017-08-17 01:42:29
#     14-16\20170817015738_100.h264.txt 2017-08-17 01:57:38 2017-08-17 01:57:45
#     14-16\20170817021250_100.h264.txt 2017-08-17 02:12:50 2017-08-17 02:12:50
#     14-16\20170817022803_100.h264.txt 2017-08-17 02:28:03 2017-08-17 02:28:03

# %%
b1 = pd.to_datetime("02:02:58")
b1
# Out:
# Timestamp('2018-12-12 02:02:58')

# %%
df_by_obj = df.set_index([ 'obj','filename']).sort_index()
df_by_obj.sample(10)
# Out:
#                                          x    y      size  seq  \
# obj filename
# 0   14-16\20170820131334_100.h264.txt  129  194  46492096   20
# 34  14-16\20170823143520_100.h264.txt  432  188  90426352  105
# 8   14-16\20170823071426_100.h264.txt  130  201  39917912   36
# 71  14-16\20170823051246_100.h264.txt  176  160  37284712   16
# 43  14-16\20170822085521_100.h264.txt  182  111  50457352   24
# 4   14-16\20170823134925_100.h264.txt  209  178  92982808   41
# 13  14-16\20170817161123_100.h264.txt  450   61       362  702
# 5   14-16\20170824024426_100.h264.txt  166  200  45312856    0
# 40  14-16\20170820101045_100.h264.txt    8  225  48242016   33
# 15  14-16\20170822114256_100.h264.txt   60  223  37285040  131
#
#                                                      time
# obj filename
# 0   14-16\20170820131334_100.h264.txt 2017-08-20 13:13:55
# 34  14-16\20170823143520_100.h264.txt 2017-08-23 14:40:40
# 8   14-16\20170823071426_100.h264.txt 2017-08-23 07:18:51
# 71  14-16\20170823051246_100.h264.txt 2017-08-23 05:23:56
# 43  14-16\20170822085521_100.h264.txt 2017-08-22 09:00:29
# 4   14-16\20170823134925_100.h264.txt 2017-08-23 13:50:26
# 13  14-16\20170817161123_100.h264.txt 2017-08-17 16:16:53
# 5   14-16\20170824024426_100.h264.txt 2017-08-24 02:45:49
# 40  14-16\20170820101045_100.h264.txt 2017-08-20 10:16:04
# 15  14-16\20170822114256_100.h264.txt 2017-08-22 11:44:59

# %%
len(df_by_obj)
# Out:
# 2997979

# %%
b1 = pd.to_datetime("2017-08-24 15:32:00")
b2 = pd.to_datetime("2017-08-24 15:32:23")

t = time_df[(time_df.time['min'].between(b1,b2)) | ((time_df.time['min'].where(time_df.time['min']<b1)&(time_df.time['max'].where(time_df.time['min']>b1))))]

# %%
dd = df_by_obj[df_by_obj.index == t.index]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-6fcffcdf6353> in <module>
# ----> 1 t.index.obj
#       2 # dd = df_by_obj[df_by_obj.index == t.index]
#
# AttributeError: 'MultiIndex' object has no attribute 'obj'

# %%
imshow(im)
for r in t.index:
    print(r)
    print(type(r))
    oo = df_by_obj.loc[r]
    plot(oo.x, oo.y)
legend()
# Out:
# (30, '14-16\\20170824152302_100.h264.txt')
# <class 'tuple'>
# (31, '14-16\\20170824152302_100.h264.txt')
# <class 'tuple'>
# (32, '14-16\\20170824152302_100.h264.txt')
# <class 'tuple'>

# %%
t
# Out:
#                                                      time
#                                                       min                 max
# obj filename
# 0   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09
# 1   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09
# 2   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09
# 3   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09
# 4   14-16\20170817012709_100.h264.txt 2017-08-17 01:27:09 2017-08-17 01:27:09

# %%
b1 = pd.to_datetime("04:00:02").time()
b2 = pd.to_datetime("09:03:02").time()

t = time_df[(time_df.time['min'].dt.time.between(b1,b2)) | ((time_df.time['min'].dt.time<b1)&(time_df.time['max'].dt.time>b2))]

# %%
imshow(im)
for r in t.index:
#     print(r)
#     print(type(r))
    oo = df_by_obj.loc[r]
    plot(oo.x, oo.y)
legend()

# %%
# Out:
#                                          x         y
#                                        min  max  min  max
# obj filename
# 338 14-16\20170823101544_100.h264.txt  259  283  271  300
# 6   14-16\20170824135152_100.h264.txt  371  371  284  284
# 74  14-16\20170819041642_100.h264.txt  180  180  353  356
# 5   14-16\20170824001205_100.h264.txt  477  478   91   94
# 10  14-16\20170820200629_100.h264.txt   12  428   64  249
# 103 14-16\20170823065916_100.h264.txt   97  104    4    5
# 39  14-16\20170823175350_100.h264.txt   17  204  121  238
# 176 14-16\20170824083308_100.h264.txt  426  430  171  172
# 89  14-16\20170824044608_100.h264.txt  205  205  342  342
# 28  14-16\20170820232512_100.h264.txt    6   26  164  172

# %%
x1,y1,x2,y2 = 0, 0, 100,100
loc_so = df[(df.x.between(x1,x2)) & (df.y.between(y1,y2))] 

loc_so.head()
loc_tf = loc_so.groupby(['obj', 'filename'])

# %%
top = loc_tf.size().sample(20)
top
# Out:
# obj  filename
# 9    14-16\20170820184930_100.h264.txt     36
# 54   14-16\20170817031337_100.h264.txt     45
# 8    14-16\20170819201320_100.h264.txt     10
# 604  14-16\20170817015738_100.h264.txt    198
# 8    14-16\20170820181901_100.h264.txt     95
# 15   14-16\20170823224010_100.h264.txt      3
# 38   14-16\20170824015829_100.h264.txt     11
# 17   14-16\20170820180348_100.h264.txt     85
# 20   14-16\20170824093359_100.h264.txt     44
# 257  14-16\20170820222427_100.h264.txt      5
# 88   14-16\20170822115630_100.h264.txt     41
# 25   14-16\20170822091032_100.h264.txt     26
# 32   14-16\20170819010919_100.h264.txt     33
# 20   14-16\20170819100555_100.h264.txt      1
# 48   14-16\20170820034923_100.h264.txt      6
# 25   14-16\20170820192001_100.h264.txt     55
# 242  14-16\20170822115630_100.h264.txt     50
# 2    14-16\20170817090436_100.h264.txt     42
# 7    14-16\20170817172721_100.h264.txt     10
# 48   14-16\20170819153959_100.h264.txt     25
# dtype: int64

# %%
imshow(im)
for r in top.index:
    oo = df_by_obj.loc[r]
    plot(oo.x, oo.y)
legend()

# %%
dx, dy = 100,100

# Custom (rgb) grid color
grid_color = [0,0,0]

# Modify the image to include the grid
im[:,::dy,:] = grid_color
# im[::dx,:,:] = grid_color

imshow(im)

# %%
ax = gca();

# %%
dx, dy = 100, 100
im1 = imread('data/paths0.png')
for i in range(dx,1000,dy):
    im1[i:i+3,:] = 0
    im1[:,i:i+3] = 0
       
imshow(im1)

# %%
b1 = pd.to_datetime("2017-08-24 15:32:00")
b2 = pd.to_datetime("2017-08-24 15:32:23")

t = df[(df.time.between(b1, b2))]
t = t.drop_duplicates(['obj', 'filename'])
t.head()
# Out:
#            x    y  obj      size  seq                           filename  \
# 2997036  259  175   28  43088232  115  14-16\20170824152302_100.h264.txt
# 2997037   45  229   29  43087928   58  14-16\20170824152302_100.h264.txt
# 2997582  276  246   30  43087880    0  14-16\20170824152302_100.h264.txt
# 2997588  219  244   31  43088008    0  14-16\20170824152302_100.h264.txt
# 2997663  155  247   32  43088232    0  14-16\20170824152302_100.h264.txt
#
#                        time
# 2997036 2017-08-24 15:32:00
# 2997037 2017-08-24 15:32:00
# 2997582 2017-08-24 15:32:16
# 2997588 2017-08-24 15:32:17
# 2997663 2017-08-24 15:32:19

# %%
def draw__(x1,y1,x2,y2):
    loc_so = df[(df.x.between(x1,x2)) & (df.y.between(y1,y2))] 
    im = imread('data/paths0.png')
    imshow(im)
    for r in top.index:
        oo = df_by_obj.loc[r]
        plot(oo.x, oo.y)
    legend()


def filter_Square(locaition_list):
    im_size = im.shape
    width = im_size[1]
    height = im_size[0]
    num_segmentation = 10
    for i in locaition_list:
        r = i[1]
        c = i[0]
        top_left = (c * width / num_segmentation , (r + 1) * height / num_segmentation)
        bottom_right = ((c + 1) * width / num_segmentation, r * height / num_segmentation)
        draw__(top_left[0],bottom_right[1],bottom_right[0],top_left[1])

filter_Square([(0,5)])

# %%
ef filter_Square(locaition_list):
   im = imread("C:\EXELLENTIM\paths0.png")
   im_size = im.shape
   width = im_size[1]
   height = im_size[0]
   num_segmentation = 10
   for i in list_test:
       r = locaition_list[1]
       c = locaition_list[0]
       top_left = (c * width / num_segmentation , (r + 1) * height / num_segmentation)
       bottom_right = ((c + 1) * width / num_segmentation, r * height / num_segmentation)
       points_in_square = df[(df.x.between(top_left[0], bottom_right[0])) & 
                             (df.y.between(bottom_right[1], top_left[1]))] #all the point in the square
       points_in_square = points_in_square.groupby(['filename', 'obj']).size()
       points_in_square = points_in_square.head(15)
       df_by_obj = df.set_index(['filename', 'obj']).sort_index()
       imshow(im)
       for t in points_in_square.index:
           s_o = df_by_obj.loc[t]
           plot(s_o.x, s_o.y, label = t[1])
       legend(loc=9, bbox_to_anchor=(1.1, 1))
filter_Square(((0, 5)))


def filter_Square(locaition_list):
   im = imread("C:\EXELLENTIM\paths0.png")
   im_size = im.shape
   width = im_size[1]
   height = im_size[0]
   num_segmentation = 10
   for i in locaition_list:
       r = i[1]
       c = i[0]
       top_left = (c * width / num_segmentation , (r + 1) * height / num_segmentation)
       bottom_right = ((c + 1) * width / num_segmentation, r * height / num_segmentation)
       points_in_square = df[(df.x.between(top_left[0], bottom_right[0])) & (df.y.between(bottom_right[1], top_left[1]))] #all the point in the square
       points_in_square = points_in_square.groupby(['filename', 'obj']).size()
       points_in_square = points_in_square.head(15)
       df_by_obj = df.set_index(['filename', 'obj']).sort_index()
       imshow(im)
       for t in points_in_square.index:
           s_o = df_by_obj.loc[t]
           plot(s_o.x, s_o.y, label = t[1])
       legend(loc=9, bbox_to_anchor=(1.1, 1))
filter_Square([(0, 5)])
